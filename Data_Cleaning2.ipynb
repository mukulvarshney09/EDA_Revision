# %% [markdown]
# <a href="https://colab.research.google.com/github/mukulvarshney09/EDA_Revision/blob/main/Data_Cleaning2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings

warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
d2 = pd.read_csv("blood_pressure.csv")

# %%
d2
# Out:
#      patient     sex agegrp  bp_before  bp_after
# 0          1    Male  30-45        143       153
# 1          2    Male  30-45        163       170
# 2          3    Male  30-45        153       168
# 3          4    Male  30-45        153       142
# 4          5    Male  30-45        146       141
# ..       ...     ...    ...        ...       ...
# 115      116  Female    60+        152       152
# 116      117  Female    60+        161       152
# 117      118  Female    60+        165       174
# 118      119  Female    60+        149       151
# 119      120  Female    60+        185       163
#
# [120 rows x 5 columns]

# %%
d2.columns
# Out:
# Index(['patient', 'sex', 'agegrp', 'bp_before', 'bp_after'], dtype='object')

# %%
d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   patient    120 non-null    int64
#  1   sex        120 non-null    object
#  2   agegrp     120 non-null    object
#  3   bp_before  120 non-null    int64
#  4   bp_after   120 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 4.8+ KB

# %%
d2.isnull().sum()
# Out:
# patient      0
# sex          0
# agegrp       0
# bp_before    0
# bp_after     0
# dtype: int64

# %%
#working on chile data - seems interesting

# %%
d3 = pd.read_csv("Chile.csv")

# %%
d3
# Out:
#       Unnamed: 0 region  population sex   age education   income  statusquo  \
# 0              1      N      175000   M  65.0         P  35000.0    1.00820
# 1              2      N      175000   M  29.0        PS   7500.0   -1.29617
# 2              3      N      175000   F  38.0         P  15000.0    1.23072
# 3              4      N      175000   F  49.0         P  35000.0   -1.03163
# 4              5      N      175000   F  23.0         S  35000.0   -1.10496
# ...          ...    ...         ...  ..   ...       ...      ...        ...
# 2695        2696      M       15000   M  42.0         P  15000.0   -1.26247
# 2696        2697      M       15000   F  28.0         P  15000.0    1.32950
# 2697        2698      M       15000   F  44.0         P  75000.0    1.42045
# 2698        2699      M       15000   M  21.0         S  75000.0    0.18315
# 2699        2700      M       15000   M  20.0        PS  35000.0    1.38179
#
#      vote
# 0       Y
# 1       N
# 2       Y
# ...

# %%
d3.head(3)
# Out:
#    Unnamed: 0 region  population sex   age education   income  statusquo vote
# 0           1      N      175000   M  65.0         P  35000.0    1.00820    Y
# 1           2      N      175000   M  29.0        PS   7500.0   -1.29617    N
# 2           3      N      175000   F  38.0         P  15000.0    1.23072    Y

# %%
d3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2700 entries, 0 to 2699
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2700 non-null   int64
#  1   region      2700 non-null   object
#  2   population  2700 non-null   int64
#  3   sex         2700 non-null   object
#  4   age         2699 non-null   float64
#  5   education   2689 non-null   object
#  6   income      2602 non-null   float64
#  7   statusquo   2683 non-null   float64
#  8   vote        2532 non-null   object
# dtypes: float64(3), int64(2), object(4)
# memory usage: 190.0+ KB

# %%
d3.drop("Unnamed: 0", axis = 1, inplace = True)

# %%
d3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2700 entries, 0 to 2699
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      2700 non-null   object
#  1   population  2700 non-null   int64
#  2   sex         2700 non-null   object
#  3   age         2699 non-null   float64
#  4   education   2689 non-null   object
#  5   income      2602 non-null   float64
#  6   statusquo   2683 non-null   float64
#  7   vote        2532 non-null   object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 168.9+ KB

# %%
d3["age"].unique()
# Out:
# array([65., 29., 38., 49., 23., 28., 26., 24., 41., 64., 19., 27., 46.,
#        36., 22., 20., 30., 67., 50., 55., 18., 58., 34., 43., 53., 32.,
#        37., 44., 33., 51., 61., 21., 70., 35., 68., 25., 66., 40., 52.,
#        54., 48., 57., 45., 31., 69., 42., 59., 63., 39., 60., 47., 62.,
#        56., nan])

# %%
d3[d3["age"].isnull()]
# Out:
#      region  population sex  age education   income  statusquo vote
# 1809     SA      250000   M  NaN         P  15000.0   -1.08507    U

# %%
d3.index[1809]
# Out:
# 1809

# %%
d3.drop(d3.index[1809])
# Out:
#      region  population sex   age education   income  statusquo vote
# 0         N      175000   M  65.0         P  35000.0    1.00820    Y
# 1         N      175000   M  29.0        PS   7500.0   -1.29617    N
# 2         N      175000   F  38.0         P  15000.0    1.23072    Y
# 3         N      175000   F  49.0         P  35000.0   -1.03163    N
# 4         N      175000   F  23.0         S  35000.0   -1.10496    N
# ...     ...         ...  ..   ...       ...      ...        ...  ...
# 2695      M       15000   M  42.0         P  15000.0   -1.26247    N
# 2696      M       15000   F  28.0         P  15000.0    1.32950    Y
# 2697      M       15000   F  44.0         P  75000.0    1.42045    Y
# 2698      M       15000   M  21.0         S  75000.0    0.18315  NaN
# 2699      M       15000   M  20.0        PS  35000.0    1.38179    Y
#
# [2699 rows x 8 columns]

# %%
d3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2700 entries, 0 to 2699
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      2700 non-null   object
#  1   population  2700 non-null   int64
#  2   sex         2700 non-null   object
#  3   age         2699 non-null   float64
#  4   education   2689 non-null   object
#  5   income      2602 non-null   float64
#  6   statusquo   2683 non-null   float64
#  7   vote        2532 non-null   object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 168.9+ KB

# %%
d3.shape
# Out:
# (2700, 8)

# %%
d3[d3["age"].isnull()]
# Out:
#      region  population sex  age education   income  statusquo vote
# 1809     SA      250000   M  NaN         P  15000.0   -1.08507    U

# %%
mean_age = d3["age"].mean()
mean_age
# Out:
# 38.54872174879585

# %%
d3.at[1809, "age"] = d3["age"].mean()

# %%
d3[d3["age"].isnull()]
# Out:
# Empty DataFrame
# Columns: [region, population, sex, age, education, income, statusquo, vote]
# Index: []

# %%
d3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2700 entries, 0 to 2699
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      2700 non-null   object
#  1   population  2700 non-null   int64
#  2   sex         2700 non-null   object
#  3   age         2700 non-null   float64
#  4   education   2689 non-null   object
#  5   income      2602 non-null   float64
#  6   statusquo   2683 non-null   float64
#  7   vote        2532 non-null   object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 168.9+ KB

# %%
d3["age"] = d3["age"].astype(int)

# %%
d3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2700 entries, 0 to 2699
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      2700 non-null   object
#  1   population  2700 non-null   int64
#  2   sex         2700 non-null   object
#  3   age         2700 non-null   int64
#  4   education   2689 non-null   object
#  5   income      2602 non-null   float64
#  6   statusquo   2683 non-null   float64
#  7   vote        2532 non-null   object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 168.9+ KB

# %%
d3["education"].unique()
# Out:
# array(['P', 'PS', 'S', nan], dtype=object)

# %%
d3["education"].isnull().sum()
# Out:
# 11

# %%
d3["education"].mode()
# Out:
# 0    S
# Name: education, dtype: object

# %%
d3["education_copy"] = d3["education"]

# %%
d3.head()
# Out:
#   region  population sex  age education   income  statusquo vote  \
# 0      N      175000   M   65         P  35000.0    1.00820    Y
# 1      N      175000   M   29        PS   7500.0   -1.29617    N
# 2      N      175000   F   38         P  15000.0    1.23072    Y
# 3      N      175000   F   49         P  35000.0   -1.03163    N
# 4      N      175000   F   23         S  35000.0   -1.10496    N
#
#   education_copy
# 0              P
# 1             PS
# 2              P
# 3              P
# 4              S

# %%
d3["education"].mode()[0]
# Out:
# 'S'

# %%
d3["education_copy"] = d3["education_copy"].fillna(d3["education"].mode()[0])

# %%
d3["education_copy"].isnull().sum()
# Out:
# 0

# %%
d3.drop("education_copy", axis = 1, inplace = True)

# %%
d3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2700 entries, 0 to 2699
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      2700 non-null   object
#  1   population  2700 non-null   int64
#  2   sex         2700 non-null   object
#  3   age         2700 non-null   int64
#  4   education   2689 non-null   object
#  5   income      2602 non-null   float64
#  6   statusquo   2683 non-null   float64
#  7   vote        2532 non-null   object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 168.9+ KB

# %%
d3["education"] = d3["education"].fillna(d3["education"].mode()[0])

# %%
d3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2700 entries, 0 to 2699
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      2700 non-null   object
#  1   population  2700 non-null   int64
#  2   sex         2700 non-null   object
#  3   age         2700 non-null   int64
#  4   education   2700 non-null   object
#  5   income      2602 non-null   float64
#  6   statusquo   2683 non-null   float64
#  7   vote        2532 non-null   object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 168.9+ KB

# %%
d3["vote"].value_counts()
# Out:
# N    889
# Y    868
# U    588
# A    187
# Name: vote, dtype: int64

# %%
d3["vote"].unique()
# Out:
# array(['Y', 'N', 'U', nan, 'A'], dtype=object)

# %%
d3.dropna(subset = "vote", inplace = True)

# %%
d3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2532 entries, 0 to 2699
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      2532 non-null   object
#  1   population  2532 non-null   int64
#  2   sex         2532 non-null   object
#  3   age         2532 non-null   int64
#  4   education   2532 non-null   object
#  5   income      2449 non-null   float64
#  6   statusquo   2519 non-null   float64
#  7   vote        2532 non-null   object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 178.0+ KB

# %%
d3["income"].mean()
# Out:
# 33971.00857492854

# %%
d3["income"].mode()[0]
# Out:
# 15000.0

# %%
d3["income"].median()
# Out:
# 15000.0

# %%
d3["income"] = d3["income"].fillna(d3["income"].mode()[0])

# %%
d3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2532 entries, 0 to 2699
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      2532 non-null   object
#  1   population  2532 non-null   int64
#  2   sex         2532 non-null   object
#  3   age         2532 non-null   int64
#  4   education   2532 non-null   object
#  5   income      2532 non-null   float64
#  6   statusquo   2519 non-null   float64
#  7   vote        2532 non-null   object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 178.0+ KB

# %%
d3["statusquo"].unique()
# Out:
# array([ 1.0082 , -1.29617,  1.23072, ...,  1.3295 ,  1.42045,  1.38179])

# %%
d3["statusquo"].isnull().sum()
# Out:
# 13

# %%
d3["statusquo"].fillna(d3["statusquo"].mean(), inplace = True)

# %%
d3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2532 entries, 0 to 2699
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      2532 non-null   object
#  1   population  2532 non-null   int64
#  2   sex         2532 non-null   object
#  3   age         2532 non-null   int64
#  4   education   2532 non-null   object
#  5   income      2532 non-null   float64
#  6   statusquo   2532 non-null   float64
#  7   vote        2532 non-null   object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 178.0+ KB

# %%
#now the data is cleaned. let's make some predictions

# %%
d3.head()
# Out:
#   region  population sex  age education   income  statusquo vote
# 0      N      175000   M   65         P  35000.0    1.00820    Y
# 1      N      175000   M   29        PS   7500.0   -1.29617    N
# 2      N      175000   F   38         P  15000.0    1.23072    Y
# 3      N      175000   F   49         P  35000.0   -1.03163    N
# 4      N      175000   F   23         S  35000.0   -1.10496    N
